# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
path='dogs-vs-cats/train/'

# %% [markdown]
# ## Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_train)
# Out:
# 2222

# %%
## One-Hot Encoding
# y_train = tf.keras.utils.to_categorical(y_train, 2)

# %% [markdown]
# # Test set (dog.12*, cat.12*)만들기

# %%
dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_test = np.concatenate((dogs,cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
dogs.shape
# Out:
# (611, 96, 96, 1)

# %%
X_test.shape, y_test.shape
# Out:
# ((1222, 96, 96, 1), (1222,))

# %%
# y_train = tf.keras.utils.to_categorical(y_train, 2)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 18,940,385
# Trainable params: 18,940,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ### 모델 학습

# %%
X_train.shape, y_train.shape
# Out:
# ((2222, 96, 96, 1), (2222,))

# %%
# model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2, shuffle=True,
#           callbacks=[checkpointer])

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2, shuffle=True,
          callbacks=[checkpointer, early_stopping_callback])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.7243 - accuracy: 0.6176
# Epoch 00001: val_loss improved from inf to 1.03094, saving model to model/dogs_vs_cats-cnn-01-1.0309.hdf5
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.7232 - accuracy: 0.6185 - val_loss: 1.0309 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6625 - accuracy: 0.6250
# Epoch 00002: val_loss improved from 1.03094 to 0.92079, saving model to model/dogs_vs_cats-cnn-02-0.9208.hdf5
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6624 - accuracy: 0.6252 - val_loss: 0.9208 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6557 - accuracy: 0.6261
# Epoch 00003: val_loss did not improve from 0.92079
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.6550 - accuracy: 0.6275 - val_loss: 1.0237 - val_accuracy: 0.0000e+00
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6571 - accuracy: 0.6267
# Epoch 00004: val_loss improved from 0.92079 to 0.87120, saving model to model/dogs_vs_cats-cnn-04-0.8712.hdf5
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6571 - accuracy: 0.6263 - val_loss: 0.8712 - val_accuracy: 0.0000e+00
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6477 - accuracy: 0.6330
# Epoch 00005: val_loss did not improve from 0.87120
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6477 - accuracy: 0.6331 - val_loss: 1.1005 - val_accuracy: 0.1011
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6397 - accuracy: 0.6574
# Epoch 00006: val_loss did not improve from 0.87120
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6399 - accuracy: 0.6567 - val_loss: 0.9172 - val_accuracy: 0.1528
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6120 - accuracy: 0.6773
# Epoch 00007: val_loss improved from 0.87120 to 0.84796, saving model to model/dogs_vs_cats-cnn-07-0.8480.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6119 - accuracy: 0.6775 - val_loss: 0.8480 - val_accuracy: 0.3146
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5809 - accuracy: 0.7017
# Epoch 00008: val_loss improved from 0.84796 to 0.73859, saving model to model/dogs_vs_cats-cnn-08-0.7386.hdf5
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5798 - accuracy: 0.7023 - val_loss: 0.7386 - val_accuracy: 0.4292
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.7335
# Epoch 00009: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.5406 - accuracy: 0.7349 - val_loss: 0.9075 - val_accuracy: 0.4764
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4903 - accuracy: 0.7648
# Epoch 00010: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.4874 - accuracy: 0.7670 - val_loss: 1.2198 - val_accuracy: 0.2989
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4772 - accuracy: 0.7864
# Epoch 00011: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.4766 - accuracy: 0.7862 - val_loss: 0.8177 - val_accuracy: 0.5506
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3901 - accuracy: 0.8278
# Epoch 00012: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.3912 - accuracy: 0.8267 - val_loss: 0.8768 - val_accuracy: 0.4966
# Epoch 13/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3236 - accuracy: 0.8568
# Epoch 00013: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.3234 - accuracy: 0.8565 - val_loss: 0.9221 - val_accuracy: 0.5933
# Epoch 14/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2528 - accuracy: 0.8994
# Epoch 00014: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.2513 - accuracy: 0.8998 - val_loss: 1.1147 - val_accuracy: 0.5955
# Epoch 15/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2007 - accuracy: 0.9170
# Epoch 00015: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.2014 - accuracy: 0.9162 - val_loss: 1.6266 - val_accuracy: 0.4539
# Epoch 16/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1420 - accuracy: 0.9409
# Epoch 00016: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.1408 - accuracy: 0.9415 - val_loss: 1.6125 - val_accuracy: 0.5528
# Epoch 17/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1206 - accuracy: 0.9574
# Epoch 00017: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.1196 - accuracy: 0.9578 - val_loss: 1.8097 - val_accuracy: 0.5281
# Epoch 18/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0644 - accuracy: 0.9807
# Epoch 00018: val_loss did not improve from 0.73859
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0640 - accuracy: 0.9809 - val_loss: 1.9726 - val_accuracy: 0.5685

# %%
from tensorflow.keras.models import load_model
# del model
model = load_model('model/dogs_vs_cats-cnn-08-0.7386.hdf5')

# %%
scores = model.evaluate(X_train, y_train, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 2222/2222 - 6s - loss: 0.6002 - accuracy: 0.6629
# MODEL ACCURACY: 0.66292
