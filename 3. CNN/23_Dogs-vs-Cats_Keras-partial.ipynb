# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
path='dogs-vs-cats/train/'

# %% [markdown]
# ## Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_train)
# Out:
# 2222

# %%
## One-Hot Encoding
# y_train = tf.keras.utils.to_categorical(y_train, 2)

# %% [markdown]
# # Test set (dog.12*, cat.12*)만들기

# %%
dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_test = np.concatenate((dogs,cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
dogs.shape
# Out:
# (611, 96, 96, 1)

# %%
X_test.shape, y_test.shape
# Out:
# ((1222, 96, 96, 1), (1222,))

# %%
# y_train = tf.keras.utils.to_categorical(y_train, 2)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 18,940,385
# Trainable params: 18,940,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ### 모델 학습

# %%
X_train.shape, y_train.shape
# Out:
# ((2222, 96, 96, 1), (2222,))

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2, shuffle=True,
          callbacks=[checkpointer])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6935 - accuracy: 0.6170
# Epoch 00001: val_loss improved from inf to 1.13459, saving model to model/dogs_vs_cats-cnn-01-1.1346.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6917 - accuracy: 0.6190 - val_loss: 1.1346 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6626 - accuracy: 0.6244
# Epoch 00002: val_loss improved from 1.13459 to 0.87143, saving model to model/dogs_vs_cats-cnn-02-0.8714.hdf5
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6625 - accuracy: 0.6241 - val_loss: 0.8714 - val_accuracy: 0.0157
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6479 - accuracy: 0.6460
# Epoch 00003: val_loss did not improve from 0.87143
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6468 - accuracy: 0.6472 - val_loss: 1.0489 - val_accuracy: 0.1034
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6393 - accuracy: 0.6636
# Epoch 00004: val_loss did not improve from 0.87143
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6374 - accuracy: 0.6652 - val_loss: 1.0421 - val_accuracy: 0.1281
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6380 - accuracy: 0.6551
# Epoch 00005: val_loss did not improve from 0.87143
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6370 - accuracy: 0.6562 - val_loss: 1.0124 - val_accuracy: 0.0989
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6045 - accuracy: 0.6818
# Epoch 00006: val_loss did not improve from 0.87143
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6040 - accuracy: 0.6815 - val_loss: 1.0074 - val_accuracy: 0.2360
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5614 - accuracy: 0.7085
# Epoch 00007: val_loss improved from 0.87143 to 0.74654, saving model to model/dogs_vs_cats-cnn-07-0.7465.hdf5
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5624 - accuracy: 0.7062 - val_loss: 0.7465 - val_accuracy: 0.4876
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5270 - accuracy: 0.7244
# Epoch 00008: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5268 - accuracy: 0.7248 - val_loss: 0.8126 - val_accuracy: 0.4629
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4744 - accuracy: 0.7727
# Epoch 00009: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.4751 - accuracy: 0.7721 - val_loss: 1.0685 - val_accuracy: 0.4764
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3937 - accuracy: 0.8097
# Epoch 00010: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.3948 - accuracy: 0.8092 - val_loss: 0.9910 - val_accuracy: 0.5618
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3384 - accuracy: 0.8466
# Epoch 00011: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.3388 - accuracy: 0.8458 - val_loss: 1.1333 - val_accuracy: 0.4899
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2619 - accuracy: 0.8898
# Epoch 00012: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.2602 - accuracy: 0.8908 - val_loss: 1.2196 - val_accuracy: 0.5978
# Epoch 13/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1842 - accuracy: 0.9244
# Epoch 00013: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.1837 - accuracy: 0.9246 - val_loss: 0.9824 - val_accuracy: 0.6899
# Epoch 14/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9523
# Epoch 00014: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.1190 - accuracy: 0.9516 - val_loss: 1.7879 - val_accuracy: 0.6135
# Epoch 15/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1063 - accuracy: 0.9631
# Epoch 00015: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.1074 - accuracy: 0.9623 - val_loss: 1.6640 - val_accuracy: 0.5865
# Epoch 16/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0696 - accuracy: 0.9761
# Epoch 00016: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0697 - accuracy: 0.9764 - val_loss: 2.8018 - val_accuracy: 0.5348
# Epoch 17/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0695 - accuracy: 0.9744
# Epoch 00017: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0699 - accuracy: 0.9741 - val_loss: 1.6400 - val_accuracy: 0.6494
# Epoch 18/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0565 - accuracy: 0.9801
# Epoch 00018: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0561 - accuracy: 0.9803 - val_loss: 1.8582 - val_accuracy: 0.6337
# Epoch 19/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0569 - accuracy: 0.9847
# Epoch 00019: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0565 - accuracy: 0.9848 - val_loss: 1.6097 - val_accuracy: 0.6921
# Epoch 20/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0447 - accuracy: 0.9864
# Epoch 00020: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0445 - accuracy: 0.9865 - val_loss: 3.0896 - val_accuracy: 0.5281
# Epoch 21/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9920
# Epoch 00021: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0295 - accuracy: 0.9921 - val_loss: 3.2925 - val_accuracy: 0.5258
# Epoch 22/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9852
# Epoch 00022: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0392 - accuracy: 0.9854 - val_loss: 2.7640 - val_accuracy: 0.5753
# Epoch 23/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9943
# Epoch 00023: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0219 - accuracy: 0.9944 - val_loss: 2.5350 - val_accuracy: 0.6000
# Epoch 24/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9932
# Epoch 00024: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0198 - accuracy: 0.9927 - val_loss: 3.6060 - val_accuracy: 0.5438
# Epoch 25/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9972
# Epoch 00025: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0151 - accuracy: 0.9972 - val_loss: 3.2644 - val_accuracy: 0.6067
# Epoch 26/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0272 - accuracy: 0.9915
# Epoch 00026: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0269 - accuracy: 0.9916 - val_loss: 2.2246 - val_accuracy: 0.6247
# Epoch 27/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9960
# Epoch 00027: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0125 - accuracy: 0.9961 - val_loss: 3.0685 - val_accuracy: 0.5888
# Epoch 28/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9949
# Epoch 00028: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0157 - accuracy: 0.9949 - val_loss: 3.0080 - val_accuracy: 0.6090
# Epoch 29/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9955
# Epoch 00029: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0147 - accuracy: 0.9955 - val_loss: 3.7053 - val_accuracy: 0.5393
# Epoch 30/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0210 - accuracy: 0.9943
# Epoch 00030: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.0210 - accuracy: 0.9944 - val_loss: 4.1672 - val_accuracy: 0.4831
# Epoch 31/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9932
# Epoch 00031: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0237 - accuracy: 0.9932 - val_loss: 2.8666 - val_accuracy: 0.5910
# Epoch 32/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0139 - accuracy: 0.9949
# Epoch 00032: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0139 - accuracy: 0.9949 - val_loss: 3.2044 - val_accuracy: 0.5573
# Epoch 33/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9955
# Epoch 00033: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0131 - accuracy: 0.9955 - val_loss: 3.0281 - val_accuracy: 0.6157
# Epoch 34/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9955
# Epoch 00034: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0161 - accuracy: 0.9955 - val_loss: 2.0958 - val_accuracy: 0.6854
# Epoch 35/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9915
# Epoch 00035: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0257 - accuracy: 0.9916 - val_loss: 2.4713 - val_accuracy: 0.6539
# Epoch 36/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0293 - accuracy: 0.9920
# Epoch 00036: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0295 - accuracy: 0.9916 - val_loss: 2.8712 - val_accuracy: 0.5933
# Epoch 37/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9977
# Epoch 00037: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0080 - accuracy: 0.9977 - val_loss: 4.4922 - val_accuracy: 0.4921
# Epoch 38/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9909
# Epoch 00038: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0223 - accuracy: 0.9904 - val_loss: 2.4839 - val_accuracy: 0.6629
# Epoch 39/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9915
# Epoch 00039: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0188 - accuracy: 0.9916 - val_loss: 2.4048 - val_accuracy: 0.6629
# Epoch 40/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0389 - accuracy: 0.9898
# Epoch 00040: val_loss did not improve from 0.74654
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.0387 - accuracy: 0.9899 - val_loss: 2.9065 - val_accuracy: 0.5326

# %%
# model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2, shuffle=True,
#           callbacks=[checkpointer, early_stopping_callback])

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-07-0.7465.hdf5')

# %%
scores = model.evaluate(X_train, y_train, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 2222/2222 - 6s - loss: 0.5663 - accuracy: 0.7066
# MODEL ACCURACY: 0.70657
